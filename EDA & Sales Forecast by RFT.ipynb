# %% [markdown]
# <a href="https://colab.research.google.com/github/henryworking/henrydata/blob/main/EDA%20%26%20Sales%20Forecast%20by%20RFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import numpy

import numpy as np
import pandas as pd

# %%
#2.Check header, row, column (df.head())
df = pd.read_csv("dlbh.csv")
df.head(3)
# Out:
#   Cấp bậc nhân viên Chi nhánh  Chiết khấu Địa chỉ Chi nhánh  \
# 0           Level 1   Đà Nẵng      3351.6      Đà Nẵng City
# 1           Level 1   Đà Nẵng     13356.0      Đà Nẵng City
# 2           Level 1   Đà Nẵng      6504.3      Đà Nẵng City
#
#          Địa chỉ khách hàng  Giá bán  Giá vốn hàng bán  Giá xuất xưởng  \
# 0         An Giang Province       84            3990.0              10
# 1         An Giang Province      315          530000.0             250
# 2  Bà Rịa–Vũng Tàu Province       73           17820.0              10
#
#   Kênh bán hàng                       Khách hàng  ...    Month Day  \
# 0        Bán lẻ        CONG TY TNHH LONG DAI TIN  ...  October  23
# 1        Đại lý  CTY CP SX VA TM TOMATO VIET NAM  ...     June  25
# 2        Đại lý        CTY TNHH NGHI DUONG CA NA  ...     July   4
#
#    Nhân viên bán hàng               Sản phẩm  Số lượng sản phẩm     Tháng  \
# 0       NGUYEN VAN LY           Đồ đông lạnh                399  Tháng 10
# 1       NGUYEN VAN LY  Dầu ăn, dầu thực phẩm               2120   Tháng 6
# 2       NGUYEN VAN LY              Đồ ăn vặt               1782   Tháng 7
#
#   Tháng (số)  Tổng tiền  hàng bán trừ chiết khấu Tổng tiền hàng bán Tỷ trọng
# 0         10                             30164.4            33516.0    0,00%
# 1          6                            654444.0           667800.0    0,03%
# 2          7                            123581.7           130086.0    0,01%
#
# [3 rows x 26 columns]

# %%
#3.Check info (df.info())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10085 entries, 0 to 10084
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Cấp bậc nhân viên                   10085 non-null  object
#  1   Chi nhánh                           10085 non-null  object
#  2   Chiết khấu                          10085 non-null  float64
#  3   Địa chỉ Chi nhánh                   10085 non-null  object
#  4   Địa chỉ khách hàng                  10085 non-null  object
#  5   Giá bán                             10085 non-null  int64
#  6   Giá vốn hàng bán                    10085 non-null  float64
#  7   Giá xuất xưởng                      10085 non-null  int64
#  8   Kênh bán hàng                       10085 non-null  object
#  9   Khách hàng                          10085 non-null  object
#  10  Loại chiết khấu                     10085 non-null  object
#  11  Loại khách hàng                     10085 non-null  object
#  12  Lợi nhuận                           10085 non-null  float64
#  13  Năm                                 10085 non-null  int64
#  14  Year                                10085 non-null  int64
#  15  Quarter                             10085 non-null  object
#  16  Month                               10085 non-null  object
#  17  Day                                 10085 non-null  int64
#  18  Nhân viên bán hàng                  10085 non-null  object
#  19  Sản phẩm                            10085 non-null  object
#  20  Số lượng sản phẩm                   10085 non-null  int64
#  21  Tháng                               10085 non-null  object
#  22  Tháng (số)                          10085 non-null  int64
#  23  Tổng tiền  hàng bán trừ chiết khấu  10085 non-null  float64
#  24  Tổng tiền hàng bán                  10085 non-null  float64
#  25  Tỷ trọng                            10085 non-null  object
# dtypes: float64(5), int64(7), object(14)
# memory usage: 2.0+ MB

# %%
# prompt: Delete % in Tỷ trọng

# Assuming 'Tỷ trọng' is the column name containing the percentage values.
df['Tỷ trọng'] = df['Tỷ trọng'].str.replace('%', '')
df.head(3)
# Out:
#   Cấp bậc nhân viên Chi nhánh  Chiết khấu Địa chỉ Chi nhánh  \
# 0           Level 1   Đà Nẵng      3351.6      Đà Nẵng City
# 1           Level 1   Đà Nẵng     13356.0      Đà Nẵng City
# 2           Level 1   Đà Nẵng      6504.3      Đà Nẵng City
#
#          Địa chỉ khách hàng  Giá bán  Giá vốn hàng bán  Giá xuất xưởng  \
# 0         An Giang Province       84            3990.0              10
# 1         An Giang Province      315          530000.0             250
# 2  Bà Rịa–Vũng Tàu Province       73           17820.0              10
#
#   Kênh bán hàng                       Khách hàng  ...    Month Day  \
# 0        Bán lẻ        CONG TY TNHH LONG DAI TIN  ...  October  23
# 1        Đại lý  CTY CP SX VA TM TOMATO VIET NAM  ...     June  25
# 2        Đại lý        CTY TNHH NGHI DUONG CA NA  ...     July   4
#
#    Nhân viên bán hàng               Sản phẩm  Số lượng sản phẩm     Tháng  \
# 0       NGUYEN VAN LY           Đồ đông lạnh                399  Tháng 10
# 1       NGUYEN VAN LY  Dầu ăn, dầu thực phẩm               2120   Tháng 6
# 2       NGUYEN VAN LY              Đồ ăn vặt               1782   Tháng 7
#
#   Tháng (số)  Tổng tiền  hàng bán trừ chiết khấu Tổng tiền hàng bán Tỷ trọng
# 0         10                             30164.4            33516.0     0,00
# 1          6                            654444.0           667800.0     0,03
# 2          7                            123581.7           130086.0     0,01
#
# [3 rows x 26 columns]

# %%
# prompt: Convert "," of Tỷ trọng to "."

df['Tỷ trọng'] = df['Tỷ trọng'].str.replace(',', '.')
df.head(3)
# Out:
#   Cấp bậc nhân viên Chi nhánh  Chiết khấu Địa chỉ Chi nhánh  \
# 0           Level 1   Đà Nẵng      3351.6      Đà Nẵng City
# 1           Level 1   Đà Nẵng     13356.0      Đà Nẵng City
# 2           Level 1   Đà Nẵng      6504.3      Đà Nẵng City
#
#          Địa chỉ khách hàng  Giá bán  Giá vốn hàng bán  Giá xuất xưởng  \
# 0         An Giang Province       84            3990.0              10
# 1         An Giang Province      315          530000.0             250
# 2  Bà Rịa–Vũng Tàu Province       73           17820.0              10
#
#   Kênh bán hàng                       Khách hàng  ...    Month Day  \
# 0        Bán lẻ        CONG TY TNHH LONG DAI TIN  ...  October  23
# 1        Đại lý  CTY CP SX VA TM TOMATO VIET NAM  ...     June  25
# 2        Đại lý        CTY TNHH NGHI DUONG CA NA  ...     July   4
#
#    Nhân viên bán hàng               Sản phẩm  Số lượng sản phẩm     Tháng  \
# 0       NGUYEN VAN LY           Đồ đông lạnh                399  Tháng 10
# 1       NGUYEN VAN LY  Dầu ăn, dầu thực phẩm               2120   Tháng 6
# 2       NGUYEN VAN LY              Đồ ăn vặt               1782   Tháng 7
#
#   Tháng (số)  Tổng tiền  hàng bán trừ chiết khấu Tổng tiền hàng bán Tỷ trọng
# 0         10                             30164.4            33516.0     0.00
# 1          6                            654444.0           667800.0     0.03
# 2          7                            123581.7           130086.0     0.01
#
# [3 rows x 26 columns]

# %%
# prompt: Transfer data type of Tỷ trọng to float64

df['Tỷ trọng'] = df['Tỷ trọng'].astype('float64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10085 entries, 0 to 10084
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Cấp bậc nhân viên                   10085 non-null  object
#  1   Chi nhánh                           10085 non-null  object
#  2   Chiết khấu                          10085 non-null  float64
#  3   Địa chỉ Chi nhánh                   10085 non-null  object
#  4   Địa chỉ khách hàng                  10085 non-null  object
#  5   Giá bán                             10085 non-null  int64
#  6   Giá vốn hàng bán                    10085 non-null  float64
#  7   Giá xuất xưởng                      10085 non-null  int64
#  8   Kênh bán hàng                       10085 non-null  object
#  9   Khách hàng                          10085 non-null  object
#  10  Loại chiết khấu                     10085 non-null  object
#  11  Loại khách hàng                     10085 non-null  object
#  12  Lợi nhuận                           10085 non-null  float64
#  13  Năm                                 10085 non-null  int64
#  14  Year                                10085 non-null  int64
#  15  Quarter                             10085 non-null  object
#  16  Month                               10085 non-null  object
#  17  Day                                 10085 non-null  int64
#  18  Nhân viên bán hàng                  10085 non-null  object
#  19  Sản phẩm                            10085 non-null  object
#  20  Số lượng sản phẩm                   10085 non-null  int64
#  21  Tháng                               10085 non-null  object
#  22  Tháng (số)                          10085 non-null  int64
#  23  Tổng tiền  hàng bán trừ chiết khấu  10085 non-null  float64
#  24  Tổng tiền hàng bán                  10085 non-null  float64
#  25  Tỷ trọng                            10085 non-null  float64
# dtypes: float64(6), int64(7), object(13)
# memory usage: 2.0+ MB

# %%
# prompt: divide Tỷ trọng by 100. Divide Tổng tiền hàng bán by 1000

# Divide 'Tỷ trọng' by 100
df['Tỷ trọng'] = df['Tỷ trọng'] / 100

# Divide 'Tổng tiền hàng bán' by 1000
df['Tổng tiền hàng bán'] = df['Tổng tiền hàng bán'] / 1000

df.head(3)
# Out:
#   Cấp bậc nhân viên Chi nhánh  Chiết khấu Địa chỉ Chi nhánh  \
# 0           Level 1   Đà Nẵng      3351.6      Đà Nẵng City
# 1           Level 1   Đà Nẵng     13356.0      Đà Nẵng City
# 2           Level 1   Đà Nẵng      6504.3      Đà Nẵng City
#
#          Địa chỉ khách hàng  Giá bán  Giá vốn hàng bán  Giá xuất xưởng  \
# 0         An Giang Province       84            3990.0              10
# 1         An Giang Province      315          530000.0             250
# 2  Bà Rịa–Vũng Tàu Province       73           17820.0              10
#
#   Kênh bán hàng                       Khách hàng  ...    Month Day  \
# 0        Bán lẻ        CONG TY TNHH LONG DAI TIN  ...  October  23
# 1        Đại lý  CTY CP SX VA TM TOMATO VIET NAM  ...     June  25
# 2        Đại lý        CTY TNHH NGHI DUONG CA NA  ...     July   4
#
#    Nhân viên bán hàng               Sản phẩm  Số lượng sản phẩm     Tháng  \
# 0       NGUYEN VAN LY           Đồ đông lạnh                399  Tháng 10
# 1       NGUYEN VAN LY  Dầu ăn, dầu thực phẩm               2120   Tháng 6
# 2       NGUYEN VAN LY              Đồ ăn vặt               1782   Tháng 7
#
#   Tháng (số)  Tổng tiền  hàng bán trừ chiết khấu Tổng tiền hàng bán Tỷ trọng
# 0         10                             30164.4             33.516   0.0000
# 1          6                            654444.0            667.800   0.0003
# 2          7                            123581.7            130.086   0.0001
#
# [3 rows x 26 columns]

# %%
# prompt: Correlation matrix for Chiết khấu, Lợi nhuận, Giá bán, Giá vốn hàng bán, Giá xuất xưởng, Tổng tiền hàng bán

# Select the columns for correlation analysis
selected_columns = ['Chiết khấu', 'Lợi nhuận', 'Giá bán', 'Giá vốn hàng bán', 'Giá xuất xưởng', 'Tổng tiền hàng bán']

# Calculate the correlation matrix for the selected columns
corr_matrix = df[selected_columns].corr()

# Display the correlation matrix
print(corr_matrix)
# Out:
#                     Chiết khấu  Lợi nhuận   Giá bán  Giá vốn hàng bán  \
# Chiết khấu            1.000000   0.040942  0.441568          0.584821
# Lợi nhuận             0.040942   1.000000  0.003768          0.026955
# Giá bán               0.441568   0.003768  1.000000          0.759901
# Giá vốn hàng bán      0.584821   0.026955  0.759901          1.000000
# Giá xuất xưởng        0.374732  -0.195154  0.891558          0.749063
# Tổng tiền hàng bán    0.612206   0.315449  0.720987          0.955391
#
#                     Giá xuất xưởng  Tổng tiền hàng bán
# Chiết khấu                0.374732            0.612206
# Lợi nhuận                -0.195154            0.315449
# Giá bán                   0.891558            0.720987
# Giá vốn hàng bán          0.749063            0.955391
# Giá xuất xưởng            1.000000            0.649150
# Tổng tiền hàng bán        0.649150            1.000000

# %%
# prompt: Remove outliers of Tổng tiền hàng bán. Replace the old data with the new version one

# Calculate the IQR (Interquartile Range)
Q1 = df['Tổng tiền hàng bán'].quantile(0.25)
Q3 = df['Tổng tiền hàng bán'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
df_filtered = df[
    (df['Tổng tiền hàng bán'] >= lower_bound) &
    (df['Tổng tiền hàng bán'] <= upper_bound)
]

# Replace the original DataFrame with the filtered one
df = df_filtered

# %%
# prompt: Analytical charts for Tổng tiền hàng bán after removing outliers out of Tổng tiền hàng bán

import matplotlib.pyplot as plt
import seaborn as sns

# Create a histogram of 'Tổng tiền hàng bán'
plt.figure(figsize=(4, 3))
plt.hist(df['Tổng tiền hàng bán'], bins=50)
plt.xlabel('Tổng tiền hàng bán')
plt.ylabel('Frequency')
plt.title('Distribution of Tổng tiền hàng bán')
plt.show()

# Create a box plot of 'Tổng tiền hàng bán'
plt.figure(figsize=(4, 3))
sns.boxplot(x=df['Tổng tiền hàng bán'])
plt.xlabel('Tổng tiền hàng bán')
plt.title('Box Plot of Tổng tiền hàng bán')
plt.show()

# Create a scatter plot of 'Tổng tiền hàng bán' against 'Lợi nhuận'
plt.figure(figsize=(4, 3))
plt.scatter(df['Tổng tiền hàng bán'], df['Lợi nhuận'])
plt.xlabel('Tổng tiền hàng bán')
plt.ylabel('Lợi nhuận')
plt.title('Scatter Plot of Tổng tiền hàng bán vs Lợi nhuận')
plt.show()

# %%
# prompt: Linear regression for a scatter plot of 'Tổng tiền hàng bán' against 'Lợi nhuận'

import matplotlib.pyplot as plt
import statsmodels.api as sm

# Add a constant term to the independent variable
X = sm.add_constant(df['Tổng tiền hàng bán'])
y = df['Lợi nhuận']

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())

# Get the predicted values
predictions = model.predict(X)

# Plot the scatter plot with the regression line
plt.figure(figsize=(4, 3))
plt.scatter(df['Tổng tiền hàng bán'], df['Lợi nhuận'])
plt.plot(df['Tổng tiền hàng bán'], predictions, color='red')
plt.xlabel('Tổng tiền hàng bán')
plt.ylabel('Lợi nhuận')
plt.title('Scatter Plot with Regression Line')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Lợi nhuận   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     1074.
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):          1.37e-223
# Time:                        10:43:36   Log-Likelihood:            -1.2029e+05
# No. Observations:                9724   AIC:                         2.406e+05
# Df Residuals:                    9722   BIC:                         2.406e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               4.468e+04    834.520     53.536      0.000     4.3e+04    4.63e+04
# Tổng tiền hàng bán    90.8924      2.773     32.777      0.000      85.457      96.328
# ==============================================================================
# Omnibus:                     1204.919   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1755.123
# Skew:                           0.931   Prob(JB):                         0.00
# Kurtosis:                       3.930   Cond. No.                         434.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# prompt: Please use LSTM model to predict each 'Chiết khấu', 'Giá bán', 'Giá vốn hàng bán', 'Giá xuất xưởng', 'Số lượng sản phẩm' for the next 30 Days (based on 'Dates'). Store those predicted values to an array named as 'random_X'. Visualize 'random_X' with future 'Dates'.

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# Select the columns for prediction
columns_to_predict = ['Chiết khấu', 'Giá bán', 'Giá vốn hàng bán', 'Giá xuất xưởng', 'Số lượng sản phẩm']

# Prepare the data for LSTM
data = df[['Dates'] + columns_to_predict].copy()
data['Dates'] = pd.to_datetime(data['Dates'])
data.set_index('Dates', inplace=True)

# Scale the data
scaler = MinMaxScaler()
data[columns_to_predict] = scaler.fit_transform(data[columns_to_predict])

# Split the data into training and testing sets
train_data = data[:-30]
test_data = data[-30:]

# Create the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_data.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(len(columns_to_predict)))
model.compile(loss='mean_squared_error', optimizer='adam')

# Prepare the data for the LSTM model
X_train = np.array(train_data).reshape(train_data.shape[0], train_data.shape[1], 1)
y_train = np.array(train_data)

# Train the LSTM model
model.fit(X_train, y_train, epochs=500, batch_size=64)

# Prepare the data for prediction
X_test = np.array(test_data).reshape(test_data.shape[0], test_data.shape[1], 1)

# Predict the values
predicted_values = model.predict(X_test)

# Inverse transform the predicted values
predicted_values = scaler.inverse_transform(predicted_values)

# Create the future dates
future_dates = pd.date_range(start=df['Dates'].max(), periods=30, freq='D')

# Store the predicted values in random_X
random_X = pd.DataFrame(predicted_values, columns=columns_to_predict, index=future_dates)

# Visualize the predictions
plt.figure(figsize=(12, 6))
for column in columns_to_predict:
  plt.plot(random_X.index, random_X[column], label=column)
plt.xlabel('Dates')
plt.ylabel('Values')
plt.title('Predicted Values for Next 30 Days')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0639
# Epoch 2/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0176
# Epoch 3/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0120
# Epoch 4/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0050
# Epoch 5/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0016
# Epoch 6/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.1522e-04
# Epoch 7/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.3065e-04
# Epoch 8/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.2094e-04
# Epoch 9/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5000e-04
# Epoch 10/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8673e-04
# Epoch 11/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2248e-04
# Epoch 12/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.0261e-04
# Epoch 13/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.9389e-04
# Epoch 14/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.
500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3551e-06
# Epoch 497/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6175e-06
# Epoch 498/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.8584e-07
# Epoch 499/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.2836e-07
# Epoch 500/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.5260e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step

# %%
# prompt: Show actual values and "predicted_values" from the start of 2021 to the end of that year by presenting data table (not by charts). If 'Chiết khấu' in predicted < 0, change it to 0.

import pandas as pd
import numpy as np
# Filter the data for the year 2021
df_2021 = df[(df['Dates'] >= '2021-01-01') & (df['Dates'] <= '2021-12-31')]

# Select the columns for prediction
columns_to_predict = ['Chiết khấu', 'Giá bán', 'Giá vốn hàng bán', 'Giá xuất xưởng', 'Số lượng sản phẩm']

# Prepare the data for LSTM
data_2021 = df_2021[['Dates'] + columns_to_predict].copy()
data_2021['Dates'] = pd.to_datetime(data_2021['Dates'])
data_2021.set_index('Dates', inplace=True)

# Scale the data
scaler = MinMaxScaler()
data_2021[columns_to_predict] = scaler.fit_transform(data_2021[columns_to_predict])

# Prepare the data for the LSTM model
X_2021 = np.array(data_2021).reshape(data_2021.shape[0], data_2021.shape[1], 1)

# Predict the values
predicted_values_2021 = model.predict(X_2021)

# Inverse transform the predicted values
predicted_values_2021 = scaler.inverse_transform(predicted_values_2021)

# Create a DataFrame for the actual values
actual_values_2021 = df_2021[columns_to_predict].copy()

# Create a DataFrame for the predicted values
predicted_df_2021 = pd.DataFrame(predicted_values_2021, columns=columns_to_predict, index=df_2021.index)

# Ensure 'Chiết khấu' is not negative
predicted_df_2021['Chiết khấu'] = predicted_df_2021['Chiết khấu'].apply(lambda x: max(0, x))

# Concatenate the actual and predicted values
result_df_2021 = pd.concat([actual_values_2021, predicted_df_2021], axis=1, keys=['Actual', 'Predicted'])

# Display the result
print(result_df_2021)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#           Actual                                                            \
#       Chiết khấu Giá bán Giá vốn hàng bán Giá xuất xưởng Số lượng sản phẩm
# 1        13356.0     315         530000.0            250              2120
# 5        37488.0     300         390500.0              5              1562
# 11        1390.8      60          11590.0             10              1159
# 15        4924.4      52           2841.0              3               947
# 21         691.2      45           2304.0              3               768
# ...          ...     ...              ...            ...               ...
# 10074    13475.7      63          21390.0             10              2139
# 10075        0.0     291          30940.0            260               119
# 10078        0.0       8           5094.0              3              1698
# 10082     2227.5      11          10125.0              5              2025
# 10083    66948.0     350         414440.0             10              1594
#
#           Predicted                                              \
#          Chiết khấu     Giá bán Giá vốn hàng bán Giá xuất xưởng
# 1      12829.905273  313.468048    528247.687500     249.115433
# 5      37139.652344  298.749298    390224.218750       4.481061
# 11      1321.124756   59.666161     11942.672852      10.079000
# 15      4846.268066   51.720860      3156.341309       3.044956
# 21       652.559692   44.638920      2777.108887       3.092763
# ...             ...         ...              ...            ...
# 10074  13406.467773   62.629776     21775.667969      10.030540
# 10075      0.000000  289.691681     31143.382812     259.636444
# 10078      0.000000    7.683168      5484.874512       3.139519
# 10082   2135.349365   10.745811     10492.964844       5.127567
# 10083  66421.890625  348.723602    412858.500000       9.269300
#
#
#       Số lượng sản phẩm
# 1           2113.836914
# 5           1554.658569
# 11          1159.282227
# 15           948.489380
# 21           769.232666
# ...                 ...
# 10074       2140.564209
# 10075        122.964287
# 10078       1701.641846
# 10082       2028.537720
# 10083       1584.427734
#
# [2268 rows x 10 columns]

# %%
# Predicted 'Chiết khấu', 'Giá bán', 'Giá vốn hàng bán', 'Giá xuất xưởng', 'Số lượng sản phẩ
chiết khấu', 'Giá bán', 'Giá vốn hàng bán', 'Giá xuất xưởng', 'Số lượng sản phẩm' by the next 30 days (based on 'Date') with 'random_X' as a sample for the next 30 days prediction.

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Select features and target variable
features = ['Chiết khấu', 'Giá bán', 'Giá vốn hàng bán', 'Giá xuất xưởng', 'Số lượng sản phẩm']
target = 'Tổng tiền hàng bán'

n = df[features]
m = df[target]

# Split data into training and testing sets
n_train, n_test, m_train, m_test = train_test_split(n, m, test_size=0.2, random_state=42)

# Train the Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(n_train, m_train)

# Make predictions on the test set
m_pred = rf_model.predict(n_test)

# Evaluate the model
mse = mean_squared_error(m_test, m_pred)
print(f"Mean Squared Error: {mse}")

# Predict 'Tổng tiền hàng bán' for the next 30 days
random_X['Tổng tiền hàng bán'] = rf_model.predict(random_X[features])

# Print the predicted values for the next 30 days
print(random_X[['Tổng tiền hàng bán']])
# Out:
# Mean Squared Error: 11.782419528313136
#             Tổng tiền hàng bán
# 2021-12-31            15.31650
# 2022-01-01            31.90655
# 2022-01-02           197.32472
# 2022-01-03           323.07020
# 2022-01-04           760.89446
# 2022-01-05            82.28329
# 2022-01-06           194.53312
# 2022-01-07            47.19862
# 2022-01-08            83.23012
# 2022-01-09           238.18530
# 2022-01-10           632.48953
# 2022-01-11            86.36813
# 2022-01-12            97.05020
# 2022-01-13           715.01478
# 2022-01-14           586.56489
# 2022-01-15           136.63049
# 2022-01-16           469.30058
# 2022-01-17           123.67577
# 2022-01-18           279.58641
# 2022-01-19           116.12611
# 2022-01-20           134.77484
# 2022-01-21            35.17551
# 2022-01-22           739.67791
# 2022-01-23           102.27693
# 2022-01-24            13.86227
# 2022-01-25            15.19345
# 2022-01-26            52.01610
# 2022-01-27            22.56648
# 2022-01-28           543.99135
# 2022-01-29            17.41875

# %%
# prompt: Please convert Year, Month, Day to datetime64
# Convert 'Year', 'Month', and 'Day' columns to datetime64
df['Dates'] = pd.to_datetime(df[['Year', 'Tháng (số)', 'Day']].astype(str).apply(lambda x: '-'.join(x), axis=1), format='%Y-%m-%d')
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
# prompt: Which Kênh bán hàng has the most Tổng tiền hàng bán all those Year

# Extract the year from the 'Dates' column
df['Year'] = df['Dates'].dt.year

# Group by 'Kênh bán hàng' and 'Year' and sum 'Tổng tiền hàng bán'
total_sales_by_channel = df.groupby(['Kênh bán hàng', 'Year'])['Tổng tiền hàng bán'].sum()

# Find the channel with the highest total sales for each year
highest_sales_channel = total_sales_by_channel.groupby('Year').idxmax()

print(highest_sales_channel)
# Out:
# Year
# 2017           (Bán buôn, 2017)
# 2018           (Bán buôn, 2018)
# 2019             (Bán lẻ, 2019)
# 2020    (Bán qua website, 2020)
# 2021    (Bán qua website, 2021)
# Name: Tổng tiền hàng bán, dtype: object
